# %%
# Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create the XML
import os
import xml.etree.ElementTree as ET
import xml.dom.minidom
from collections import defaultdict

def group_files_by_prefix(files):
    grouped_files = defaultdict(list)
    for file in files:
        prefix = file.split('-')[0]
        grouped_files[prefix].append(file)
    return grouped_files

def read_translations(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read().strip().split('\n')

def generate_xml_for_group(files, base_dir, output_dir):
    languages = {'txt': 'amis', 'zh': 'zhinese', 'en': 'english'}
    sentences = {}

    # Read files and sort content by language
    for file in files:
        extension = file.split('.')[-1]
        language = languages[extension]
        sentences[language] = read_translations(os.path.join(base_dir, file))

    video_id = files[0].split('-')[0]  # Assumes video ID is the prefix before the first dash in filename
    source_url = f"https://ailt.ilrdf.org.tw/colloquial/{video_id}"

    # Create XML structure
    root = ET.Element("TEXT", {"xml:lang": "amis", "source": source_url})
    num_sentences = len(sentences[next(iter(sentences))])  # Assuming all files have the same number of lines

    for i in range(num_sentences):
        s_element = ET.SubElement(root, "S", id=str(i))
        for lang, sents in sentences.items():
            if lang == 'amis':
                form_element = ET.SubElement(s_element, "FORM")
                form_element.text = sents[i]
            else:
                transl_element = ET.SubElement(s_element, "TRANSL", {"xml:lang": lang[:2]})
                transl_element.text = sents[i]

    # Convert to pretty XML
    xml_str = xml.dom.minidom.parseString(ET.tostring(root)).toprettyxml(indent="    ")

    # Save XML to file
    output_path = os.path.join(output_dir, f"{video_id}.xml")
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(xml_str)

# Example usage
base_dir = '/content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos'
output_dir = '/content/drive/MyDrive/formosan_mt_project/xml/amis_videos'
files = os.listdir(base_dir)
grouped_files = group_files_by_prefix(files)

for prefix, group in grouped_files.items():
    generate_xml_for_group(group, base_dir, output_dir)

# %%
import os

def count_english_words_in_files(directory):
    total_words = 0

    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.en'):
                # Construct the full path of the file
                path = os.path.join(root, file)
                try:
                    # Open the file and read the contents
                    with open(path, 'r', encoding='utf-8') as f:
                        words = f.read().split()
                        num_words = len(words)
                        total_words += num_words
                        print(f"{path}: {num_words} words")
                except Exception as e:
                    print(f"Failed to read {file}: {e}")

    # Print the total number of words in all .en files in the directory and subdirectories
    print(f"Total words in directory and subdirectories: {total_words}")

# Usage example
directory = '/content/drive/MyDrive/formosan_mt_project/translations/amis'
count_english_words_in_files(directory)
# Out:
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_bible/1-bible-english.en: 23824 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/719-video-english.en: 1846 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/57-video-english.en: 965 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/759-video-english.en: 1520 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/758-video-english.en: 1668 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/744-video-english.en: 1626 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/741-video-english.en: 1861 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/25-video-english.en: 286 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/731-video-english.en: 1115 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/727-video-english.en: 1826 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/729-video-english.en: 1726 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/730-video-english.en: 1694 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/725-video-english.en: 1106 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/763-video-english.en: 1187 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/32-video-english.en: 381 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/713-video-english.en: 1624 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/136-video-english.en: 827 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/158-video-english.en: 1467 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/568-video-english.en: 1879 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/45-video-english.en: 576 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/109-video-english.en: 1613 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/112-video-english.en: 1368 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/650-video-english.en: 2504 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/111-video-english.en: 1301 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/110-video-english.en: 1460 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/151-video-english.en: 1627 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/149-video-english.en: 2015 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/669-video-english.en: 1640 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/116-video-english.en: 2070 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/178-video-english.en: 1311 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/695-video-english.en: 1907 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/193-video-english.en: 1513 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/579-video-english.en: 2188 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/618-video-english.en: 2133 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/118-video-english.en: 1400 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/144-video-english.en: 2330 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/681-video-english.en: 2041 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/113-video-english.en: 1934 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/633-video-english.en: 1090 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/643-video-english.en: 1805 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/611-video-english.en: 437 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/122-video-english.en: 654 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/145-video-english.en: 1514 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/705-video-english.en: 1238 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/200-video-english.en: 1502 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/107-video-english.en: 1374 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/108-video-english.en: 1390 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/609-video-english.en: 690 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/146-video-english.en: 2069 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/154-video-english.en: 531 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/176-video-english.en: 1828 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/180-video-english.en: 1027 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/569-video-english.en: 1355 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/142-video-english.en: 1175 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/704-video-english.en: 1943 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/150-video-english.en: 1730 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/157-video-english.en: 2378 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/673-video-english.en: 623 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/162-video-english.en: 2063 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/682-video-english.en: 998 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/698-video-english.en: 1675 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/219-video-english.en: 1244 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/115-video-english.en: 1796 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/148-video-english.en: 2218 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/166-video-english.en: 1078 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/170-video-english.en: 405 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/120-video-english.en: 1304 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/175-video-english.en: 1737 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/188-video-english.en: 1971 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/581-video-english.en: 1048 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/117-video-english.en: 1508 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/672-video-english.en: 573 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/171-video-english.en: 1837 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/718-video-english.en: 1519 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/220-video-english.en: 2840 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/119-video-english.en: 1209 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/132-video-english.en: 1795 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/156-video-english.en: 1606 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/167-video-english.en: 1566 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/168-video-english.en: 1466 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/179-video-english.en: 1938 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/184-video-english.en: 1362 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/195-video-english.en: 1417 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/223-video-english.en: 936 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/224-video-english.en: 2191 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/591-video-english.en: 1480 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/127-video-english.en: 1724 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/128-video-english.en: 1845 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/153-video-english.en: 1319 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/155-video-english.en: 1515 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/159-video-english.en: 1306 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/161-video-english.en: 960 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/163-video-english.en: 1526 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/165-video-english.en: 1340 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/197-video-english.en: 1821 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/720-video-english.en: 1246 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/227-video-english.en: 2091 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/229-video-english.en: 1767 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/130-video-english.en: 1754 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/133-video-english.en: 1367 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/134-video-english.en: 1051 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/143-video-english.en: 1591 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/152-video-english.en: 1609 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/671-video-english.en: 1563 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/169-video-english.en: 1417 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/183-video-english.en: 1322 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/190-video-english.en: 1049 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/196-video-english.en: 1830 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/198-video-english.en: 1908 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/201-video-english.en: 1146 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/202-video-english.en: 2181 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/204-video-english.en: 1971 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/205-video-english.en: 1573 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/209-video-english.en: 1773 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/212-video-english.en: 1557 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/222-video-english.en: 1647 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/230-video-english.en: 1528 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/233-video-english.en: 1903 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/570-video-english.en: 1325 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/574-video-english.en: 1415 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/613-video-english.en: 1427 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/114-video-english.en: 1139 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/121-video-english.en: 1879 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/635-video-english.en: 2442 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/124-video-english.en: 1491 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/638-video-english.en: 1708 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/137-video-english.en: 1095 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/147-video-english.en: 2301 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/662-video-english.en: 948 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/173-video-english.en: 1629 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/174-video-english.en: 892 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/182-video-english.en: 1459 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/185-video-english.en: 1319 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/192-video-english.en: 1341 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/194-video-english.en: 1313 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/199-video-english.en: 1257 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/206-video-english.en: 1862 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/207-video-english.en: 1353 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/210-video-english.en: 1642 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/214-video-english.en: 1660 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/226-video-english.en: 2016 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/231-video-english.en: 1642 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/234-video-english.en: 1646 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/608-video-english.en: 1386 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/123-video-english.en: 1807 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/126-video-english.en: 1247 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/129-video-english.en: 2283 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/135-video-english.en: 322 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/139-video-english.en: 1420 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/140-video-english.en: 1188 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/141-video-english.en: 1870 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/670-video-english.en: 1461 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/164-video-english.en: 1344 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/177-video-english.en: 1378 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/181-video-english.en: 1198 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/186-video-english.en: 1241 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/189-video-english.en: 789 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/191-video-english.en: 715 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/211-video-english.en: 2036 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/215-video-english.en: 1395 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/216-video-english.en: 1272 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/217-video-english.en: 1494 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/218-video-english.en: 1254 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/221-video-english.en: 2468 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/225-video-english.en: 1421 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/232-video-english.en: 2101 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/577-video-english.en: 1931 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/125-video-english.en: 654 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/131-video-english.en: 1292 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/138-video-english.en: 2161 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/160-video-english.en: 959 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/172-video-english.en: 1842 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/697-video-english.en: 1904 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/187-video-english.en: 2019 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/700-video-english.en: 1814 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/203-video-english.en: 1826 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/208-video-english.en: 1666 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/213-video-english.en: 1221 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/228-video-english.en: 2408 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/630-video-english.en: 1899 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/715-video-english.en: 1766 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/738-video-english.en: 818 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/686-video-english.en: 1586 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/724-video-english.en: 1067 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_videos/708-video-english.en: 732 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_apology/6-english-apology.en: 1949 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_virginia_fey/4-fey-english.en: 12527 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_glosbe/0-glosbe-english.en: 37418 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/17-Amis_Nr-pear_minzhu.en: 492 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/15-Amis_Nr-pear_cinhua.en: 268 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/7-Amis_Nr-frog_ofad.en: 392 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/3-Amis_Nr-crab_panay.en: 165 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/8-Amis_Nr-frog_zuomei.en: 418 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/2-Amis_Conv-talking_tamih_panay.en: 499 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/6-Amis_Nr-frog_minzhu.en: 478 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/14-Amis_Nr-peanut_panay.en: 105 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/1-Amis_Conv-farming_marang_furayang.en: 581 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/5-Amis_Nr-frog_cinhua.en: 397 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/18-Amis_Nr-pear_panay.en: 426 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/9-Amis_Nr-intro_ofad.en: 310 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/11-Amis_Nr-pear_tamih.en: 76 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/13-Amis_Nr-intro_tamih.en: 876 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/12-Amis_Nr-intro_Panay.en: 77 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/10-Amis_Nr-pear_zuomei.en: 396 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/4-Amis_Nr-custom_Liu.en: 705 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_ntu/16-Amis_Nr-pear_lungi.en: 216 words
# /content/drive/MyDrive/formosan_mt_project/translations/amis/amis_parallel_data_2022/2-2022study-english.en: 43475 words
# Total words in directory and subdirectories: 403794
